# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Load Dataset

# %%
path = '..\\data\\flood_zones.csv'
df = pd.read_csv(path)
df.head()
# Out:
#         zone_id risk_level   latitude  longitude  radius_km
# 0  Flood_Zone_1       High  17.426944  78.511921   2.613463
# 1  Flood_Zone_2       High  17.469971  78.386998   1.285328
# 2  Flood_Zone_3       High  17.338032  78.424907   2.711006

# %%
df.shape
# Out:
# (3, 5)
