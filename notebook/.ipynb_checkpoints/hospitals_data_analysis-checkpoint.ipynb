# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Load Dataset

# %%
path = '..\\data\\hospitals.csv'
df = pd.read_csv(path)
df.head()
# Out:
#   hospital_id                   type   latitude  longitude
# 0         H_1  Primary Health Centre  17.430806  78.446042
# 1         H_2  Primary Health Centre  17.351013  78.453358
# 2         H_3  Primary Health Centre  17.482062  78.543806
# 3         H_4  Primary Health Centre  17.391972  78.507953
# 4         H_5  Primary Health Centre  17.363489  78.420382

# %%
df.shape
# Out:
# (5, 4)
