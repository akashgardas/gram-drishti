# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Load Dataset

# %%
path = '..\\data\\villages.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    village_id       name  population   latitude  longitude
# 0           1  Village_1        1830  17.331544  78.388874
# 1           2  Village_2        3925  17.333270  78.406621
# 2           3  Village_3        4095  17.373196  78.562986
# 3           4  Village_4        4306  17.351885  78.525824
# 4           5  Village_5        1410  17.288982  78.554511

# %%
df.shape
# Out:
# (50, 5)
